# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
a = np.array([1.139 - 0.00059*i + 1.9e-6*i*i - 1.38e-9*i*i*i for i in range(30,200)])
b = [i for i in range(30,200)]

plt.plot(b, a)

# %%
a_d = np.array([(1.139 - 0.00059*i + 1.9e-6*i*i - 1.38e-9*i*i*i)*\
     (1 - (0.0996 - 8.33e-5*i + 4.7e-8*i*i)) for i in range(30,200)])
b_d = [i for i in range(30,200)]

plt.plot(b, a_d)

# %%
((a - a_d).mean() / a).mean()
# Out:
# 0.090835094064825983

# %%
(1 - 1.12 * 0.1) / (1-0.1)
# Out:
# 0.9866666666666667

# %%
(1 - 1.12 * 1.09 * 0.1) / (1-0.1)
# Out:
# 0.9754666666666667

# %%
n=1000
a = plt.hist((np.random.rand(n) + np.random.rand(n))/4. + 0.35, normed=True, bins=30)

# %%
n=1000
a = plt.hist((np.random.rand(n) *  np.random.rand(n)), normed=True, bins=30)

# %%
n=1000
a = plt.hist((np.random.rand(n)**2), normed=True, bins=30)

# %%
n=1000
a = np.concatenate( ( (np.random.rand(n) + np.random.rand(n))/2, np.random.rand(n) *  np.random.rand(n)) )
a = plt.hist(a, normed=True, bins=30)
# Out:
# C:\Users\thoth\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
np.concatenate?
